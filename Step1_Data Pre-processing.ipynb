# %%
import pandas as pd

# %%
dataset=pd.read_csv("Churn Prediction.csv")

# %%
dataset.head(3)
# Out:
#   account_id subscription_id  start_date    end_date   plan_tier  No.of users  \
# 0   A-3c1a3f        S-8cec59  23-12-2023  12-04-2024  Enterprise           14
# 1   A-9b9fe9        S-0f6f44  11-06-2024         NaN         Pro           17
# 2   A-659280        S-51c0d1  25-11-2024         NaN  Enterprise           62
#
#    mrr_amount  arr_amount  is_trial  upgrade_flag  ...  is_trial.1  \
# 0        2786       33432     False         False  ...       False
# 1         833        9996     False         False  ...       False
# 2           0           0      True          True  ...        True
#
#    churn_flag.1 churn_event_id  churn_date reason_code refund_amount_usd  \
# 0         False            NaN         NaN         NaN               NaN
# 1         False       C-16ef52  04-09-2024    features               0.0
# 2          True            NaN         NaN         NaN               NaN
#
#   preceding_upgrade_flag preceding_downgrade_flag is_reactivation  \
# ...

# %%
dataset.columns
# Out:
# Index(['account_id', 'subscription_id', 'start_date', 'end_date', 'plan_tier',
#        'No.of users', 'mrr_amount', 'arr_amount', 'is_trial', 'upgrade_flag',
#        'downgrade_flag', 'churn_flag', 'billing_frequency', 'auto_renew_flag',
#        'account_name', 'industry', 'country', 'signup_date', 'referral_source',
#        'plan_tier.1', 'seats', 'is_trial.1', 'churn_flag.1', 'churn_event_id',
#        'churn_date', 'reason_code', 'refund_amount_usd',
#        'preceding_upgrade_flag', 'preceding_downgrade_flag', 'is_reactivation',
#        'feedback_text'],
#       dtype='object')

# %%
ds=dataset.drop(["is_trial.1", 'churn_flag.1','account_id', 'subscription_id', 'plan_tier.1',"end_date",'signup_date','churn_date',"churn_event_id"], axis=1)

# %%
ds.head(3)
# Out:
#    start_date   plan_tier  No.of users  mrr_amount  arr_amount  is_trial  \
# 0  23-12-2023  Enterprise           14        2786       33432     False
# 1  11-06-2024         Pro           17         833        9996     False
# 2  25-11-2024  Enterprise           62           0           0      True
#
#    upgrade_flag  downgrade_flag  churn_flag billing_frequency  ...  industry  \
# 0         False           False        True           monthly  ...  DevTools
# 1         False           False       False           monthly  ...    EdTech
# 2          True           False       False            annual  ...   FinTech
#
#   country referral_source seats reason_code  refund_amount_usd  \
# 0      UK           event     1         NaN                NaN
# 1      AU           other     5    features                0.0
# 2      IN           event    13         NaN                NaN
#
#   preceding_upgrade_flag  preceding_downgrade_flag is_reactivation  \
# ...

# %%
ds.columns
# Out:
# Index(['start_date', 'plan_tier', 'No.of users', 'mrr_amount', 'arr_amount',
#        'is_trial', 'upgrade_flag', 'downgrade_flag', 'churn_flag',
#        'billing_frequency', 'auto_renew_flag', 'account_name', 'industry',
#        'country', 'referral_source', 'seats', 'reason_code',
#        'refund_amount_usd', 'preceding_upgrade_flag',
#        'preceding_downgrade_flag', 'is_reactivation', 'feedback_text'],
#       dtype='object')

# %%
ds.rename(columns={'start_date':"Account creation date", "seats":"Licensed user count", 
                   'mrr_amount': "Monthly revenue",'arr_amount':"Annual revenue", 'is_trial': "Trial status",
                 'preceding_upgrade_flag':"Had upgrade within 90 days", 'preceding_downgrade_flag': "Had downgrade within 90 days" }, inplace=True)

# %%
ds.columns
# Out:
# Index(['Account creation date', 'plan_tier', 'No.of users', 'Monthly revenue',
#        'Annual revenue', 'Trial status', 'upgrade_flag', 'downgrade_flag',
#        'churn_flag', 'billing_frequency', 'auto_renew_flag', 'account_name',
#        'industry', 'country', 'referral_source', 'Licensed user count',
#        'reason_code', 'refund_amount_usd', 'Had upgrade within 90 days',
#        'Had downgrade within 90 days', 'is_reactivation', 'feedback_text'],
#       dtype='object')

# %%
ds.head(3)
# Out:
#   Account creation date   plan_tier  No.of users  Monthly revenue  \
# 0            23-12-2023  Enterprise           14             2786
# 1            11-06-2024         Pro           17              833
# 2            25-11-2024  Enterprise           62                0
#
#    Annual revenue  Trial status  upgrade_flag  downgrade_flag  churn_flag  \
# 0           33432         False         False           False        True
# 1            9996         False         False           False       False
# 2               0          True          True           False       False
#
#   billing_frequency  ...  industry country referral_source  \
# 0           monthly  ...  DevTools      UK           event
# 1           monthly  ...    EdTech      AU           other
# 2            annual  ...   FinTech      IN           event
#
#   Licensed user count reason_code  refund_amount_usd  \
# 0                   1         NaN                NaN
# ...

# %%
ds.isnull().sum()
# Out:
# Account creation date              0
# plan_tier                          0
# No.of users                        0
# Monthly revenue                    0
# Annual revenue                     0
# Trial status                       0
# upgrade_flag                       0
# downgrade_flag                     0
# churn_flag                         0
# billing_frequency                  0
# auto_renew_flag                    0
# account_name                       0
# industry                           0
# country                            0
# referral_source                    0
# Licensed user count                0
# reason_code                     2587
# refund_amount_usd               2587
# Had upgrade within 90 days      2587
# Had downgrade within 90 days    2587
# is_reactivation                 2587
# feedback_text                   3261
# dtype: int64

# %%
ds.isna().sum()
# Out:
# Account creation date              0
# plan_tier                          0
# No.of users                        0
# Monthly revenue                    0
# Annual revenue                     0
# Trial status                       0
# upgrade_flag                       0
# downgrade_flag                     0
# churn_flag                         0
# billing_frequency                  0
# auto_renew_flag                    0
# account_name                       0
# industry                           0
# country                            0
# referral_source                    0
# Licensed user count                0
# reason_code                     2587
# refund_amount_usd               2587
# Had upgrade within 90 days      2587
# Had downgrade within 90 days    2587
# is_reactivation                 2587
# feedback_text                   3261
# dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Account creation date         5000 non-null   object
#  1   plan_tier                     5000 non-null   object
#  2   No.of users                   5000 non-null   int64
#  3   Monthly revenue               5000 non-null   int64
#  4   Annual revenue                5000 non-null   int64
#  5   Trial status                  5000 non-null   bool
#  6   upgrade_flag                  5000 non-null   bool
#  7   downgrade_flag                5000 non-null   bool
#  8   churn_flag                    5000 non-null   bool
#  9   billing_frequency             5000 non-null   object
#  10  auto_renew_flag               5000 non-null   bool
#  11  account_name                  5000 non-null   object
#  12  industry                      5000 non-null   object
# ...

# %%
ds["refund_amount_usd"] = ds["refund_amount_usd"].fillna(0)

# %%
ds["reason_code"]= ds["reason_code"].fillna("Not Available")

# %%
ds["feedback_text"]=ds["feedback_text"].fillna("Not Available")

# %%
ds.isnull().sum()
# Out:
# Account creation date              0
# plan_tier                          0
# No.of users                        0
# Monthly revenue                    0
# Annual revenue                     0
# Trial status                       0
# upgrade_flag                       0
# downgrade_flag                     0
# churn_flag                         0
# billing_frequency                  0
# auto_renew_flag                    0
# account_name                       0
# industry                           0
# country                            0
# referral_source                    0
# Licensed user count                0
# reason_code                        0
# refund_amount_usd                  0
# Had upgrade within 90 days      2587
# Had downgrade within 90 days    2587
# is_reactivation                 2587
# feedback_text                      0
# dtype: int64

# %%
nan_rows = ds[ds['is_reactivation'].isna()]
nan_rows
# Out:
#      Account creation date   plan_tier  No.of users  Monthly revenue  \
# 0               23-12-2023  Enterprise           14             2786
# 2               25-11-2024  Enterprise           62                0
# 3               23-11-2024  Enterprise            5              995
# 7               23-12-2024       Basic           16              304
# 8               27-11-2024  Enterprise           23             4577
# ...                    ...         ...          ...              ...
# 4989            25-07-2024  Enterprise           13             2587
# 4992            03-09-2024  Enterprise           27             5373
# 4994            15-08-2023  Enterprise           33             6567
# 4996            05-12-2024         Pro           23             1127
# 4997            15-12-2024         Pro           25             1225
#
#       Annual revenue  Trial status  upgrade_flag  downgrade_flag  churn_flag  \
# ...

# %%
ds["Had upgrade within 90 days"]=ds["Had upgrade within 90 days"].fillna("Unknown")
ds["Had downgrade within 90 days"]=ds["Had downgrade within 90 days"].fillna("Unknown")

# %%
ds.isnull().sum()
# Out:
# Account creation date           0
# plan_tier                       0
# No.of users                     0
# Monthly revenue                 0
# Annual revenue                  0
# Trial status                    0
# upgrade_flag                    0
# downgrade_flag                  0
# churn_flag                      0
# billing_frequency               0
# auto_renew_flag                 0
# account_name                    0
# industry                        0
# country                         0
# referral_source                 0
# Licensed user count             0
# reason_code                     0
# refund_amount_usd               0
# Had upgrade within 90 days      0
# Had downgrade within 90 days    0
# is_reactivation                 0
# feedback_text                   0
# dtype: int64

# %%
ds.head(5)
# Out:
#   Account creation date   plan_tier  No.of users  Monthly revenue  \
# 0            23-12-2023  Enterprise           14             2786
# 1            11-06-2024         Pro           17              833
# 2            25-11-2024  Enterprise           62                0
# 3            23-11-2024  Enterprise            5              995
# 4            10-01-2024  Enterprise           27             5373
#
#    Annual revenue  Trial status  upgrade_flag  downgrade_flag  churn_flag  \
# 0           33432         False         False           False        True
# 1            9996         False         False           False       False
# 2               0          True          True           False       False
# 3           11940         False         False           False        True
# 4           64476         False         False           False       False
#
#   billing_frequency  ...       industry country referral_source  \
# ...

# %%
ds["plan_tier"].value_counts()
# Out:
# plan_tier
# Enterprise    1723
# Pro           1675
# Basic         1602
# Name: count, dtype: int64

# %%
ds["Annual revenue"].value_counts()
# Out:
# Annual revenue
# 0         778
# 38208      56
# 11172      51
# 31044      50
# 10584      44
#          ...
# 19380       1
# 105252      1
# 181488      1
# 389244      1
# 77616       1
# Name: count, Length: 306, dtype: int64

# %%
ds.columns
# Out:
# Index(['Account creation date', 'plan_tier', 'No.of users', 'Monthly revenue',
#        'Annual revenue', 'Trial status', 'upgrade_flag', 'downgrade_flag',
#        'churn_flag', 'billing_frequency', 'auto_renew_flag', 'account_name',
#        'industry', 'country', 'referral_source', 'Licensed user count',
#        'reason_code', 'refund_amount_usd', 'Had upgrade within 90 days',
#        'Had downgrade within 90 days', 'is_reactivation', 'feedback_text'],
#       dtype='object')

# %%
ds.to_csv("Churn_Prediction_Preprocessed.csv", index=False)
